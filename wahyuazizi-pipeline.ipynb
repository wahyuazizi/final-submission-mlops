# %% [markdown]
# # Import Library

# %%
import os
import sys
from typing import Text

from absl import logging
from tfx.orchestration import metadata, pipeline
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner

# %% [markdown]
# # Set Variables

# %%
PIPELINE_NAME = "wahyuazizi-pipeline"

# Pipeline inputs
DATA_ROOT = "data"
TRANSFORM_MODULE_FILE = "modules/employee_performance_transform.py"
TRAINER_MODULE_FILE = "modules/employee_performance_trainer.py"
TUNER_MODULE_FILE = "modules/employee_performance_tuner.py"

# Requirement_file = os.path.join(root, "requirements.txt")

# Pipeline outputs
OUTPUT_BASE = "output"
serving_model_dir = os.path.join(OUTPUT_BASE, "serving_model")
pipeline_root = os.path.join(OUTPUT_BASE, PIPELINE_NAME)
metadata_path = os.path.join(pipeline_root, "metadata.sqlite")

# %% [markdown]
# # Run Pipeline

# %%
def init_local_pipeline(
        components, pipeline_root: Text
) -> pipeline.Pipeline:
    logging.info(f"Pipeline root set to: {pipeline_root}")
    beam_args = [
        "--direct_running_mode=multi_processing"
        # 0 auto-detect based on the number of CPUs available
        # during execution time.
        "---direct_num_workers=0"
    ]

    return pipeline.Pipeline(
        pipeline_name=PIPELINE_NAME,
        pipeline_root=pipeline_root,
        components=components,
        enable_cache=True,
        metadata_connection_config=metadata.sqlite_metadata_connection_config(
            metadata_path
        ),
        eam_pipeline_args=beam_args
    )


if __name__ == "__main__":
    logging.set_verbosity(logging.INFO)

    from modules.components import init_components

    components = init_components(
        DATA_ROOT,
        training_module=TRAINER_MODULE_FILE,
        transform_module=TRANSFORM_MODULE_FILE,
        tuning_module=TUNER_MODULE_FILE,
        training_steps=5000,
        eval_steps=1000,
        serving_model_dir=serving_model_dir,
    )

    pipeline = init_local_pipeline(components, pipeline_root)
    BeamDagRunner().run(pipeline=pipeline)
# Out:
# Trial 18 Complete [00h 00m 40s]
# val_sparse_categorical_accuracy: 0.7825000286102295
#
# Best val_sparse_categorical_accuracy So Far: 0.7827187776565552
# Total elapsed time: 00h 07m 28s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:absl:Finished tuning... Tuner ID: tuner0
# INFO:absl:Best HyperParameters: {'space': [{'class_name': 'Int', 'config': {'name': 'fc_units', 'default': None, 'conditions': [], 'min_value': 16, 'max_value': 64, 'step': 16, 'sampling': None}}, {'class_name': 'Choice', 'config': {'name': 'lr', 'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}}], 'values': {'fc_units': 16, 'lr': 0.0001, 'tuner/epochs': 3, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0}}
# INFO:absl:Best Hyperparameters are written to output\wahyuazizi-pipeline\Tuner\best_hyperparameters\7\best_hyperparameters.txt.
# INFO:absl:Tuner results are written to output\wahyuazizi-pipeline\Tuner\tuner_results\7\tuner_results.json.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 7 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'tuner_results': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Tuner\\tuner_results\\7"
# , artifact_type: name: "TunerResults"
# )], 'best_hyperparameters': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Tuner\\best_hyperparameters\\7"
# , artifact_type: name: "HyperParameters"
# )]}) for execution 7
# Results summary
# Results in output\wahyuazizi-pipeline\Tuner\.system\executor_execution\7\.temp\7\kt_hyperband
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x000002552E7A7D00>
# Trial summary
# Hyperparameters:
# fc_units: 16
# lr: 0.0001
# tuner/epochs: 3
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.7827187776565552
# Trial summary
# Hyperparameters:
# fc_units: 16
# lr: 0.0001
# tuner/epochs: 9
# tuner/initial_epoch: 3
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0007
# Score: 0.7826562523841858
# Trial summary
# Hyperparameters:
# fc_units: 64
# lr: 0.0001
# tuner/epochs: 3
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.7826250195503235
# Trial summary
# Hyperparameters:
# fc_units: 48
# lr: 0.0001
# tuner/epochs: 3
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.7825937271118164
# Trial summary
# Hyperparameters:
# fc_units: 64
# lr: 0.0001
# tuner/epochs: 9
# tuner/initial_epoch: 3
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0011
# Score: 0.7825937271118164
# Trial summary
# Hyperparameters:
# fc_units: 48
# lr: 0.0001
# tuner/epochs: 9
# tuner/initial_epoch: 3
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0008
# Score: 0.7825624942779541
# Trial summary
# Hyperparameters:
# fc_units: 16
# lr: 0.0001
# tuner/epochs: 25
# tuner/initial_epoch: 9
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0012
# Score: 0.7825624942779541
# Trial summary
# Hyperparameters:
# fc_units: 32
# lr: 0.0001
# tuner/epochs: 3
# tuner/initial_epoch: 0
# tuner/bracket: 2
# tuner/round: 0
# Score: 0.7825312614440918
# Trial summary
# Hyperparameters:
# fc_units: 32
# lr: 0.0001
# tuner/epochs: 9
# tuner/initial_epoch: 3
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0000
# Score: 0.7825312614440918
# Trial summary
# Hyperparameters:
# fc_units: 64
# lr: 0.0001
# tuner/epochs: 25
# tuner/initial_epoch: 9
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 0013
# Score: 0.7825000286102295
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Tuner is finished.
# INFO:absl:node Trainer is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "wahyuazizi-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20250320-112345.778709"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "wahyuazizi-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "hyperparameters"
#     value {
#       channels {
#         producer_node_query {
#           id: "Tuner"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.Tuner"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "HyperParameters"
#           }
#         }
#         output_key: "best_hyperparameters"
#       }
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 1000,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "employee_performance_trainer@output\\wahyuazizi-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+8ba46569f86eb76aa21ded128e330b712a120e1f18377b27aa6d9b2f9cd70ed3-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 5000,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# upstream_nodes: "Tuner"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Trainer] Resolved inputs: ({'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "output\\wahyuazizi-pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441043417
# last_update_time_since_epoch: 1742441043417
# , artifact_type: id: 20
# name: "Schema"
# )], 'hyperparameters': [Artifact(artifact: id: 14
# type_id: 28
# uri: "output\\wahyuazizi-pipeline\\Tuner\\best_hyperparameters\\7"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441603998
# last_update_time_since_epoch: 1742441603998
# , artifact_type: id: 28
# name: "HyperParameters"
# )], 'transform_graph': [Artifact(artifact: id: 7
# type_id: 23
# uri: "output\\wahyuazizi-pipeline\\Transform\\transform_graph\\5"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441151530
# last_update_time_since_epoch: 1742441151530
# , artifact_type: id: 23
# name: "TransformGraph"
# )], 'examples': [Artifact(artifact: id: 4
# type_id: 16
# uri: "output\\wahyuazizi-pipeline\\Transform\\transformed_examples\\5"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"eval\", \"train\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441151527
# last_update_time_since_epoch: 1742441151527
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 8
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=8, input_dict={'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "output\\wahyuazizi-pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441043417
# last_update_time_since_epoch: 1742441043417
# , artifact_type: id: 20
# name: "Schema"
# )], 'hyperparameters': [Artifact(artifact: id: 14
# type_id: 28
# uri: "output\\wahyuazizi-pipeline\\Tuner\\best_hyperparameters\\7"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441603998
# last_update_time_since_epoch: 1742441603998
# , artifact_type: id: 28
# name: "HyperParameters"
# )], 'transform_graph': [Artifact(artifact: id: 7
# type_id: 23
# uri: "output\\wahyuazizi-pipeline\\Transform\\transform_graph\\5"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441151530
# last_update_time_since_epoch: 1742441151530
# , artifact_type: id: 23
# name: "TransformGraph"
# )], 'examples': [Artifact(artifact: id: 4
# type_id: 16
# uri: "output\\wahyuazizi-pipeline\\Transform\\transformed_examples\\5"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"eval\", \"train\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441151527
# last_update_time_since_epoch: 1742441151527
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]}, output_dict=defaultdict(<class 'list'>, {'model': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Trainer\\model\\8"
# , artifact_type: name: "Model"
# base_type: MODEL
# )], 'model_run': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Trainer\\model_run\\8"
# , artifact_type: name: "ModelRun"
# )]}), exec_properties={'custom_config': 'null', 'eval_args': '{\n  "num_steps": 1000,\n  "splits": [\n    "eval"\n  ]\n}', 'train_args': '{\n  "num_steps": 5000,\n  "splits": [\n    "train"\n  ]\n}', 'module_path': 'employee_performance_trainer@output\\wahyuazizi-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+8ba46569f86eb76aa21ded128e330b712a120e1f18377b27aa6d9b2f9cd70ed3-py3-none-any.whl'}, execution_output_uri='output\\wahyuazizi-pipeline\\Trainer\\.system\\executor_execution\\8\\executor_output.pb', stateful_working_dir='output\\wahyuazizi-pipeline\\Trainer\\.system\\stateful_working_dir\\20250320-112345.778709', tmp_dir='output\\wahyuazizi-pipeline\\Trainer\\.system\\executor_execution\\8\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "wahyuazizi-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20250320-112345.778709"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "wahyuazizi-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "hyperparameters"
#     value {
#       channels {
#         producer_node_query {
#           id: "Tuner"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.Tuner"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "HyperParameters"
#           }
#         }
#         output_key: "best_hyperparameters"
#       }
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 1000,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "employee_performance_trainer@output\\wahyuazizi-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+8ba46569f86eb76aa21ded128e330b712a120e1f18377b27aa6d9b2f9cd70ed3-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 5000,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# upstream_nodes: "Tuner"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "wahyuazizi-pipeline"
# , pipeline_run_id='20250320-112345.778709')
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# INFO:absl:udf_utils.get_fn {'custom_config': 'null', 'eval_args': '{\n  "num_steps": 1000,\n  "splits": [\n    "eval"\n  ]\n}', 'train_args': '{\n  "num_steps": 5000,\n  "splits": [\n    "train"\n  ]\n}', 'module_path': 'employee_performance_trainer@output\\wahyuazizi-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+8ba46569f86eb76aa21ded128e330b712a120e1f18377b27aa6d9b2f9cd70ed3-py3-none-any.whl'} 'run_fn'
# INFO:absl:Installing 'output\\wahyuazizi-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+8ba46569f86eb76aa21ded128e330b712a120e1f18377b27aa6d9b2f9cd70ed3-py3-none-any.whl' to a temporary directory.
# INFO:absl:Executing: ['c:\\Users\\Lenovo\\anaconda3\\envs\\submission\\python.exe', '-m', 'pip', 'install', '--target', 'C:\\Users\\Lenovo\\AppData\\Local\\Temp\\tmp02ju6y2i', 'output\\wahyuazizi-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+8ba46569f86eb76aa21ded128e330b712a120e1f18377b27aa6d9b2f9cd70ed3-py3-none-any.whl']
# INFO:absl:Successfully installed 'output\\wahyuazizi-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+8ba46569f86eb76aa21ded128e330b712a120e1f18377b27aa6d9b2f9cd70ed3-py3-none-any.whl'.
# INFO:absl:Training model.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  BusinessUnit_xf (InputLayer)   [(None, 11)]         0           []
#
#  EmployeeStatus_xf (InputLayer)  [(None, 3)]         0           []
#
#  EmployeeType_xf (InputLayer)   [(None, 4)]          0           []
#
#  PayZone_xf (InputLayer)        [(None, 4)]          0           []
#
#  EmployeeClassificationType_xf   [(None, 4)]         0           []
#  (InputLayer)
#
#  DepartmentType_xf (InputLayer)  [(None, 7)]         0           []
#
#  GenderCode_xf (InputLayer)     [(None, 3)]          0           []
#
#  RaceDesc_xf (InputLayer)       [(None, 6)]          0           []
#
#  MaritalDesc_xf (InputLayer)    [(None, 5)]          0           []
#
#  TrainingType_xf (InputLayer)   [(None, 3)]          0           []
#
#  TrainingOutcome_xf (InputLayer  [(None, 5)]         0           []
#  )
#
#  CurrentEmployeeRating_xf (Inpu  [(None, 1)]         0           []
#  tLayer)
#
#  EngagementScore_xf (InputLayer  [(None, 1)]         0           []
#  )
#
#  SatisfactionScore_xf (InputLay  [(None, 1)]         0           []
#  er)
#
#  Work-LifeBalanceScore_xf (Inpu  [(None, 1)]         0           []
#  tLayer)
#
#  TrainingDurationDays_xf (Input  [(None, 1)]         0           []
#  Layer)
#
#  TrainingCost_xf (InputLayer)   [(None, 1)]          0           []
#
#  Age_xf (InputLayer)            [(None, 1)]          0           []
#
#  concatenate_1 (Concatenate)    (None, 62)           0           ['BusinessUnit_xf[0][0]',
#                                                                   'EmployeeStatus_xf[0][0]',
#                                                                   'EmployeeType_xf[0][0]',
#                                                                   'PayZone_xf[0][0]',
#                                                                   'EmployeeClassificationType_xf[0
#                                                                  ][0]',
#                                                                   'DepartmentType_xf[0][0]',
#                                                                   'GenderCode_xf[0][0]',
#                                                                   'RaceDesc_xf[0][0]',
#                                                                   'MaritalDesc_xf[0][0]',
#                                                                   'TrainingType_xf[0][0]',
#                                                                   'TrainingOutcome_xf[0][0]',
#                                                                   'CurrentEmployeeRating_xf[0][0]'
#                                                                  , 'EngagementScore_xf[0][0]',
#                                                                   'SatisfactionScore_xf[0][0]',
#                                                                   'Work-LifeBalanceScore_xf[0][0]'
#                                                                  , 'TrainingDurationDays_xf[0][0]'
#                                                                  , 'TrainingCost_xf[0][0]',
#                                                                   'Age_xf[0][0]']
#
#  dense_4 (Dense)                (None, 256)          16128       ['concatenate_1[0][0]']
#
#  dense_5 (Dense)                (None, 16)           4112        ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 16)           272         ['dense_5[0][0]']
#
#  dropout_1 (Dropout)            (None, 16)           0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 4)            68          ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 20,580
# Trainable params: 20,580
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/15
# c:\Users\Lenovo\anaconda3\envs\submission\lib\site-packages\keras\backend.py:5582: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 4991/5000 [============================>.] - ETA: 0s - loss: 0.6029 - sparse_categorical_accuracy: 0.7949
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.76500, saving model to output\wahyuazizi-pipeline\Trainer\model\8\Format-Serving
# WARNING:absl:Function `_wrapped_model` contains input name(s) BusinessUnit_xf, EmployeeStatus_xf, EmployeeType_xf, PayZone_xf, EmployeeClassificationType_xf, DepartmentType_xf, GenderCode_xf, RaceDesc_xf, MaritalDesc_xf, TrainingType_xf, TrainingOutcome_xf, CurrentEmployeeRating_xf, EngagementScore_xf, SatisfactionScore_xf, Work-LifeBalanceScore_xf, TrainingDurationDays_xf, TrainingCost_xf, Age_xf with unsupported characters which will be renamed to businessunit_xf, employeestatus_xf, employeetype_xf, payzone_xf, employeeclassificationtype_xf, departmenttype_xf, gendercode_xf, racedesc_xf, maritaldesc_xf, trainingtype_xf, trainingoutcome_xf, currentemployeerating_xf, engagementscore_xf, satisfactionscore_xf, work_lifebalancescore_xf, trainingdurationdays_xf, trainingcost_xf, age_xf in the SavedModel.
# INFO:tensorflow:Assets written to: output\wahyuazizi-pipeline\Trainer\model\8\Format-Serving\assets
# INFO:tensorflow:Assets written to: output\wahyuazizi-pipeline\Trainer\model\8\Format-Serving\assets
# 5000/5000 [==============================] - 33s 6ms/step - loss: 0.6026 - sparse_categorical_accuracy: 0.7949 - val_loss: 0.8338 - val_sparse_categorical_accuracy: 0.7650
# Epoch 2/15
# 4992/5000 [============================>.] - ETA: 0s - loss: 0.2359 - sparse_categorical_accuracy: 0.9229
# Epoch 2: val_sparse_categorical_accuracy did not improve from 0.76500
# 5000/5000 [==============================] - 33s 7ms/step - loss: 0.2357 - sparse_categorical_accuracy: 0.9229 - val_loss: 1.6794 - val_sparse_categorical_accuracy: 0.7088
# Epoch 3/15
# 4994/5000 [============================>.] - ETA: 0s - loss: 0.0541 - sparse_categorical_accuracy: 0.9908
# Epoch 3: val_sparse_categorical_accuracy did not improve from 0.76500
# 5000/5000 [==============================] - 28s 6ms/step - loss: 0.0540 - sparse_categorical_accuracy: 0.9908 - val_loss: 2.7478 - val_sparse_categorical_accuracy: 0.6948
# Epoch 4/15
# 4998/5000 [============================>.] - ETA: 0s - loss: 0.0127 - sparse_categorical_accuracy: 0.9985
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.76500
# 5000/5000 [==============================] - 30s 6ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9985 - val_loss: 3.7332 - val_sparse_categorical_accuracy: 0.7052
# Epoch 5/15
# 4994/5000 [============================>.] - ETA: 0s - loss: 0.0056 - sparse_categorical_accuracy: 0.9991
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.76500
# 5000/5000 [==============================] - 28s 6ms/step - loss: 0.0056 - sparse_categorical_accuracy: 0.9991 - val_loss: 4.3484 - val_sparse_categorical_accuracy: 0.6948
# Epoch 6/15
# 4998/5000 [============================>.] - ETA: 0s - loss: 0.0035 - sparse_categorical_accuracy: 0.9993
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.76500
# 5000/5000 [==============================] - 27s 5ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9993 - val_loss: 4.9326 - val_sparse_categorical_accuracy: 0.7053
# Epoch 7/15
# 4999/5000 [============================>.] - ETA: 0s - loss: 0.0026 - sparse_categorical_accuracy: 0.9995
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.76500
# 5000/5000 [==============================] - 29s 6ms/step - loss: 0.0026 - sparse_categorical_accuracy: 0.9995 - val_loss: 5.3008 - val_sparse_categorical_accuracy: 0.6824
# Epoch 8/15
# 4991/5000 [============================>.] - ETA: 0s - loss: 0.0022 - sparse_categorical_accuracy: 0.9995
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.76500
# 5000/5000 [==============================] - 31s 6ms/step - loss: 0.0022 - sparse_categorical_accuracy: 0.9995 - val_loss: 5.7075 - val_sparse_categorical_accuracy: 0.7053
# Epoch 9/15
# 5000/5000 [==============================] - ETA: 0s - loss: 0.0018 - sparse_categorical_accuracy: 0.9996
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.76500
# 5000/5000 [==============================] - 38s 8ms/step - loss: 0.0018 - sparse_categorical_accuracy: 0.9996 - val_loss: 5.9629 - val_sparse_categorical_accuracy: 0.6929
# Epoch 10/15
# 4987/5000 [============================>.] - ETA: 0s - loss: 0.0017 - sparse_categorical_accuracy: 0.9996
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.76500
# 5000/5000 [==============================] - 32s 6ms/step - loss: 0.0017 - sparse_categorical_accuracy: 0.9996 - val_loss: 6.2446 - val_sparse_categorical_accuracy: 0.6929
# Epoch 11/15
# 4998/5000 [============================>.] - ETA: 0s - loss: 0.0015 - sparse_categorical_accuracy: 0.9997
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.76500
# 5000/5000 [==============================] - 37s 7ms/step - loss: 0.0015 - sparse_categorical_accuracy: 0.9997 - val_loss: 6.3682 - val_sparse_categorical_accuracy: 0.6579
# Epoch 11: early stopping
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:Assets written to: output\wahyuazizi-pipeline\Trainer\model\8\Format-Serving\assets
# INFO:tensorflow:Assets written to: output\wahyuazizi-pipeline\Trainer\model\8\Format-Serving\assets
# INFO:absl:Training complete. Model written to output\wahyuazizi-pipeline\Trainer\model\8\Format-Serving. ModelRun written to output\wahyuazizi-pipeline\Trainer\model_run\8
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 8 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'model': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Trainer\\model\\8"
# , artifact_type: name: "Model"
# base_type: MODEL
# )], 'model_run': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Trainer\\model_run\\8"
# , artifact_type: name: "ModelRun"
# )]}) for execution 8
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Trainer is finished.
# INFO:absl:node Evaluator is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "wahyuazizi-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20250320-112345.778709"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "wahyuazizi-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"AUC\"\n        },\n        {\n          \"class_name\": \"Precision\"\n        },\n        {\n          \"class_name\": \"Recall\"\n        },\n        {\n          \"class_name\": \"ExampleCount\"\n        },\n        {\n          \"class_name\": \"SparseCategoricalAccuracy\",\n          \"threshold\": {\n            \"change_threshold\": {\n              \"absolute\": 0.0001,\n              \"direction\": \"HIGHER_IS_BETTER\"\n            },\n            \"value_threshold\": {\n              \"lower_bound\": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"PerformanceScore\"\n    }\n  ],\n  \"slicing_specs\": [\n    {},\n    {\n      \"feature_keys\": [\n        \"EmployeeClassificationType\",\n        \"GenderCode\"\n      ]\n    }\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Trainer"
# upstream_nodes: "latest_blessed_model_resolver"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Evaluator] Resolved inputs: ({'baseline_model': [], 'examples': [Artifact(artifact: id: 1
# type_id: 16
# uri: "output\\wahyuazizi-pipeline\\CsvExampleGen\\examples\\2"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:312538,xor_checksum:1742291879,sum_checksum:1742291879"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441031204
# last_update_time_since_epoch: 1742441031204
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'model': [Artifact(artifact: id: 15
# type_id: 30
# uri: "output\\wahyuazizi-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441967275
# last_update_time_since_epoch: 1742441967275
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 9
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=9, input_dict={'baseline_model': [], 'examples': [Artifact(artifact: id: 1
# type_id: 16
# uri: "output\\wahyuazizi-pipeline\\CsvExampleGen\\examples\\2"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:312538,xor_checksum:1742291879,sum_checksum:1742291879"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441031204
# last_update_time_since_epoch: 1742441031204
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'model': [Artifact(artifact: id: 15
# type_id: 30
# uri: "output\\wahyuazizi-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441967275
# last_update_time_since_epoch: 1742441967275
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )]}, output_dict=defaultdict(<class 'list'>, {'evaluation': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Evaluator\\evaluation\\9"
# , artifact_type: name: "ModelEvaluation"
# )], 'blessing': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Evaluator\\blessing\\9"
# , artifact_type: name: "ModelBlessing"
# )]}), exec_properties={'example_splits': 'null', 'eval_config': '{\n  "metrics_specs": [\n    {\n      "metrics": [\n        {\n          "class_name": "AUC"\n        },\n        {\n          "class_name": "Precision"\n        },\n        {\n          "class_name": "Recall"\n        },\n        {\n          "class_name": "ExampleCount"\n        },\n        {\n          "class_name": "SparseCategoricalAccuracy",\n          "threshold": {\n            "change_threshold": {\n              "absolute": 0.0001,\n              "direction": "HIGHER_IS_BETTER"\n            },\n            "value_threshold": {\n              "lower_bound": 0.5\n            }\n          }\n        }\n      ]\n    }\n  ],\n  "model_specs": [\n    {\n      "label_key": "PerformanceScore"\n    }\n  ],\n  "slicing_specs": [\n    {},\n    {\n      "feature_keys": [\n        "EmployeeClassificationType",\n        "GenderCode"\n      ]\n    }\n  ]\n}', 'fairness_indicator_thresholds': 'null'}, execution_output_uri='output\\wahyuazizi-pipeline\\Evaluator\\.system\\executor_execution\\9\\executor_output.pb', stateful_working_dir='output\\wahyuazizi-pipeline\\Evaluator\\.system\\stateful_working_dir\\20250320-112345.778709', tmp_dir='output\\wahyuazizi-pipeline\\Evaluator\\.system\\executor_execution\\9\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "wahyuazizi-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
# ...
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000025519BEFF70> and <keras.engine.input_layer.InputLayer object at 0x0000025539932D30>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000025523598880> and <keras.engine.input_layer.InputLayer object at 0x000002552E762BB0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000025523598880> and <keras.engine.input_layer.InputLayer object at 0x000002552E762BB0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x00000255375ED640> and <keras.engine.input_layer.InputLayer object at 0x000002551C0DB640>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x00000255375ED640> and <keras.engine.input_layer.InputLayer object at 0x000002551C0DB640>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000025548DB04F0> and <keras.engine.input_layer.InputLayer object at 0x000002553E4E9970>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x0000025548DB04F0> and <keras.engine.input_layer.InputLayer object at 0x000002553E4E9970>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002552F9192E0> and <keras.engine.input_layer.InputLayer object at 0x000002554083D3D0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000002552F9192E0> and <keras.engine.input_layer.InputLayer object at 0x000002554083D3D0>).
# INFO:absl:Evaluation complete. Results written to output\wahyuazizi-pipeline\Evaluator\evaluation\9.
# INFO:absl:Checking validation results.
# INFO:absl:Blessing result True written to output\wahyuazizi-pipeline\Evaluator\blessing\9.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 9 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'evaluation': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Evaluator\\evaluation\\9"
# , artifact_type: name: "ModelEvaluation"
# )], 'blessing': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Evaluator\\blessing\\9"
# , artifact_type: name: "ModelBlessing"
# )]}) for execution 9
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Evaluator is finished.
# INFO:absl:node Pusher is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "wahyuazizi-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20250320-112345.778709"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "wahyuazizi-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"output\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Pusher] Resolved inputs: ({'model': [Artifact(artifact: id: 15
# type_id: 30
# uri: "output\\wahyuazizi-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441967275
# last_update_time_since_epoch: 1742441967275
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'model_blessing': [Artifact(artifact: id: 18
# type_id: 34
# uri: "output\\wahyuazizi-pipeline\\Evaluator\\blessing\\9"
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "output\\wahyuazizi-pipeline\\Trainer\\model\\8"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 15
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441993772
# last_update_time_since_epoch: 1742441993772
# , artifact_type: id: 34
# name: "ModelBlessing"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 10
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=10, input_dict={'model': [Artifact(artifact: id: 15
# type_id: 30
# uri: "output\\wahyuazizi-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441967275
# last_update_time_since_epoch: 1742441967275
# , artifact_type: id: 30
# name: "Model"
# base_type: MODEL
# )], 'model_blessing': [Artifact(artifact: id: 18
# type_id: 34
# uri: "output\\wahyuazizi-pipeline\\Evaluator\\blessing\\9"
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "output\\wahyuazizi-pipeline\\Trainer\\model\\8"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 15
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1742441993772
# last_update_time_since_epoch: 1742441993772
# , artifact_type: id: 34
# name: "ModelBlessing"
# )]}, output_dict=defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Pusher\\pushed_model\\10"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}), exec_properties={'custom_config': 'null', 'push_destination': '{\n  "filesystem": {\n    "base_directory": "output\\\\serving_model"\n  }\n}'}, execution_output_uri='output\\wahyuazizi-pipeline\\Pusher\\.system\\executor_execution\\10\\executor_output.pb', stateful_working_dir='output\\wahyuazizi-pipeline\\Pusher\\.system\\stateful_working_dir\\20250320-112345.778709', tmp_dir='output\\wahyuazizi-pipeline\\Pusher\\.system\\executor_execution\\10\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "wahyuazizi-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20250320-112345.778709"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "wahyuazizi-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250320-112345.778709"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "wahyuazizi-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"output\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "wahyuazizi-pipeline"
# , pipeline_run_id='20250320-112345.778709')
# INFO:absl:Model version: 1742441994
# INFO:absl:Model written to serving path output\serving_model\1742441994.
# INFO:absl:Model pushed to output\wahyuazizi-pipeline\Pusher\pushed_model\10.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 10 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "output\\wahyuazizi-pipeline\\Pusher\\pushed_model\\10"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}) for execution 10
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Pusher is finished.
